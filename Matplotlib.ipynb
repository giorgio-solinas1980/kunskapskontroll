# %% [markdown]
# # Matplotlib
# Read the tutorials: "Basic Usage" and "Pyplot Tutorial" in the link: https://matplotlib.org/stable/tutorials/index.html before solving the exercises below. The "Pyplot Tutorial" you do not read in detail but it is good to know about since the fact that there are two approaches to plotting can be confusing if you are not aware of both of the approaches.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Plotting in Matplotlib can be done in either of two ways, which ones? Which way is the recommended approach?

# %% [markdown]
# Object Oriented approach (which is the recomended one) and the Matlab/Pyplot style

# %% [markdown]
# ### Explain shortly what a figure, axes, axis and an artist is in Matplotlib.

# %% [markdown]
# A Figure is an Artist that hols all the elements used to create a plot. Artists like Axes, Axis, Titles, etc are all contained in a Figure. It is a sort of main canvas for the plot. A Figure can have 1 or more Axes. An Axes is the area where the plot/subplots will be displayed: it includes the Artists needed to configurate our data system (Axis), the plotted data, ticks, labels and titles. We call the methods to create the plotting directly from the Axes. The Axis are the reference for the plot setting the scale and the limit, the ticks. An Artist is basically anything we see needed to gerenare our plot!

# %% [markdown]
# ### When plotting in Matplotlib, what is the expected input data type?

# %% [markdown]
# Numpy arrays or objectes that can be converted in numpy arrays!

# %% [markdown]
# ### Create a plot of the function y = x^2 [from -4 to 4, hint use the np.linspace function] both in the object-oriented approach and the pyplot approach. Your plot should have a title and axis-labels.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x= np.linspace(-4,4)
y=x**2
fig, ax = plt.subplots()
ax.plot(x,y)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_title('My first plot')
# Out:
# Text(0.5, 1.0, 'My first plot')

# %% [markdown]
# ### Create a figure containing 2  subplots where the first is a scatter plot and the second is a bar plot. You have the data below.

# %%
# Data for scatter plot
np.random.seed(15)
random_data_x = np.random.randn(100)
random_data_y = np.random.randn(100)
x = np.linspace(-2, 2, 100)
y = x**2
fig, ax = plt.subplots(1,2, figsize = (12,6))
ax[0].plot(x,y,"b--", label="y=x²")
ax[0].scatter(random_data_x, random_data_y, c="red", label="random")
ax[0].set_title("Random numbers vs parabola")
ax[0].legend()
# Data for bar plot
fruit_data = {'grapes': 22, 'apple': 8, 'orange': 15, 'lemon': 20, 'lime': 25}
names = list(fruit_data.keys())
values = list(fruit_data.values())
ax[1].bar(names, values, color=["green","red","orange","yellow", "lime" ])
ax[1].set_title("Amount of fruits")
# Out:
# Text(0.5, 1.0, 'Amount of fruits')

# %% [markdown]
# In the scatter plot data there were also the data for y=x^2, so since I wasn't sure what to do I added that plot too
